# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time
from urllib.parse import quote
from io import StringIO

# %% [markdown]
# ## Test API

# %%
# Tone is a FILTER in the query string, not a separate param
params = {
    "query": "trump crypto tone:>5 sourcelang:English domainis:nytimes.com",  # Only positive articles
    "mode": "artlist",
    "format": "json",
    "timespan": "24hours",
    "maxrecords": 5
}

# Tone filtering options:
"query": "bitcoin tone:>5"      # Positive (tone > 5)
"query": "bitcoin tone:<-5"     # Negative (tone < -5)
"query": "bitcoin tone:>10"     # Very positive
"query": "bitcoin tone:<-10"    # Very negative

# All params explained:

# IN QUERY STRING (part of "query" param):
# - sourcelang:English          # Language filter
# - sourcecountry:US            # Country (US, GB, DE, etc.)
# - domainis:coindesk.com       # Exact domain
# - domain:cnn.com              # Domain + subdomains
# - tone:>5 or tone:<-5         # Sentiment filter (-100 to +100)
# - theme:ECON_CRYPTOCURRENCY   # GDELT theme
# - near5:"word1 word2"         # Words within 5 words of each other

# SEPARATE PARAMS:
params = {
    "mode": "artlist",           # artlist, timelinevol, timelinevolraw, imagecollagelist
    "format": "json",            # json, csv, html
    "timespan": "3months",       # 15min, 1hour, 24hours, 7days, 1month, 3months
    "maxrecords": 250,           # 1-250 (only for artlist mode)
    "sort": "DateDesc",          # DateDesc, DateAsc, ToneDesc, ToneAsc (only artlist)
    "startdatetime": "20250101000000",  # YYYYMMDDHHMMSS format
    "enddatetime": "20250115000000"     # YYYYMMDDHHMMSS format
}

# Note: Tone scores in results are -100 to +100 scale
# Articles already include tone scores in response - you don't "add" them

# %%
# Define personalities and crypto keywords
personalities = [
    "Elon Musk", "Trump", "Vitalik Buterin", "Changpeng Zhao", 
    "Jack Dorsey", "Brian Armstrong", "Janet Yellen", "Jerome Powell"
]

crypto_keywords = ["Bitcoin", "Ethereum", "cryptocurrency"]

# Define newspapers (domains)
newspapers = [
    "wsj.com", "ft.com", "nytimes.com", "bloomberg.com", "coindesk.com"
]

# %%
base_url = "https://api.gdeltproject.org/api/v2/doc/doc"

# Define personalities and crypto keywords
personality = "Trump"

crypto_keywords = ["bitcoin"]

# Define newspapers (domains)
newspapers = [
    "wsj.com", "ft.com", "nytimes.com", "bloomberg.com", "coindesk.com"
]

# Build query string
domain_filters = " OR ".join([f"domainis:{d}" for d in newspapers])
if len(crypto_keywords) > 1:
    crypto_keywords_ = ' OR '.join(crypto_keywords)
    query_terms = f'{personality} AND ({crypto_keywords_})'
else:
    crypto_keywords_ = crypto_keywords[0]
    query_terms = f'{personality} AND {crypto_keywords_}'
full_query = f"{query_terms} sourcelang:English ({domain_filters})"



# using proximity

personality = "Trump"
crypto_keywords = ["bitcoin"]
newspapers = ["wsj.com", "ft.com", "nytimes.com", "bloomberg.com", "coindesk.com"]
proximity = 15  # number of words between personality and crypto keyword

# Build domain filter
domain_filters = " OR ".join([f"domainis:{d}" for d in newspapers])

# Build crypto keyword part
if len(crypto_keywords) > 1:
    crypto_keywords_ = ' OR '.join(crypto_keywords)
else:
    crypto_keywords_ = crypto_keywords[0]

# Build nearX query for each crypto keyword
# e.g., near5:"Trump Bitcoin" OR near5:"Trump Ethereum"
near_queries = ' OR '.join([f'near{proximity}:"{personality} {c}"' for c in crypto_keywords_ .split(' OR ')])

# Combine with domains and language
if len(crypto_keywords) > 1:
    full_query = f"({near_queries}) sourcelang:English ({domain_filters})"
else:
    full_query = f"{near_queries} sourcelang:English ({domain_filters})"



params = {
    "query": full_query,  
    "mode": "artlist",
    "format": "csv",
    "startdatetime": "20250720000000",
    "enddatetime": "20250930235959",
    "sort" : "datedesc",
    "maxrecords": 250
}

response = requests.get(base_url, params=params)
# data_dict = response.json()
csv_data = StringIO(response.text)

# Read CSV into a DataFrame
df = pd.read_csv(csv_data)
# Out:
#   Content-type: text/html; charset=utf-8
# 0           Server: GDELT API Server 2.0
# 1         Access-Control-Allow-Origin: *
# 2                 Timing-Allow-Origin: *
# 3        X-XSS-Protection: 1; mode=block
# 4                          Invalid mode.

# %%
df
# Out:
#                                                   URL  MobileURL  \
# 0   https://www.coindesk.com/business/2025/09/23/c...        NaN
# 1   https://www.coindesk.com/markets/2025/09/10/me...        NaN
# 2   https://www.bloomberg.com:443/news/articles/20...        NaN
# 3   https://www.coindesk.com/markets/2025/08/29/bi...        NaN
# 4   https://www.bloomberg.com/news/articles/2025-0...        NaN
# 5   https://www.coindesk.com/policy/2025/08/20/the...        NaN
# 6   https://www.coindesk.com/policy/2025/08/20/tru...        NaN
# 7   https://www.coindesk.com/policy/2025/08/20/win...        NaN
# 8   https://www.coindesk.com/markets/2025/08/14/u-...        NaN
# 9   https://www.coindesk.com/markets/2025/08/14/bi...        NaN
# 10  https://www.coindesk.com/policy/2025/08/07/don...        NaN
# 11  https://www.bloomberg.com/news/articles/2025-0...        NaN
# 12  https://www.coindesk.com/markets/2025/08/01/bi...        NaN
#
#                    Date                                              Title
# 0   2025-09-23 17:00:00  Crypto VC Firm Archetype Launches $100M Fund t...
# 1   2025-09-10 12:30:00  Metaplanet ( 3350 ) to Raise $1 . 4B in Intern...
# 2   2025-09-10 03:15:00  How Bitcoin , Ether Are Rallying as Trump Embr...
# 3   2025-08-29 15:15:00  Bitcoin Price ( BTC ) News : Losses Extend to ...
# 4   2025-08-28 04:00:00  HK Official Skips Crypto Event to Avoid Eric T...
# 5   2025-08-21 02:00:00  There  No Question In The World  Bitcoin Will ...
# 6   2025-08-21 02:00:00  Trump Crypto  Conflicts of Interest  Are  Bloc...
# 7   2025-08-20 21:00:00  Winklevoss Twins Heave $21M Toward Republicans...
# 8   2025-08-14 23:30:00  Bitcoin News ( BTC ): Strategic Reserve Purcha...
# 9   2025-08-14 13:45:00  Bitcoin Price News : What Next as BTC Crosses ...
# 10  2025-08-07 22:45:00  Donald Trump Signs Order Letting Crypto Into 4...
# 11  2025-08-03 03:00:00      Bitcoin Price : BTC Falls to Three - Week Low
# 12  2025-08-01 21:00:00  Bitcoin News Today : BTC , ETH Start August on...

# %%
data_dict
# Out:
# {'articles': [{'url': 'https://www.coindesk.com/business/2025/09/23/crypto-vc-firm-archetype-launches-usd100m-fund-to-back-early-blockchain-startups',
#    'url_mobile': '',
#    'title': 'Crypto VC Firm Archetype Launches $100M Fund to Back Early Blockchain Startup',
#    'seendate': '20250923T170000Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/2bb99ef791db1603a7268017479b6182f3952bc2-1920x1080.jpg',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.coindesk.com/markets/2025/09/10/metaplanet-to-raise-usd1-4-billion-in-international-share-sale-stock-jumps-16',
#    'url_mobile': '',
#    'title': 'Metaplanet ( 3350 ) to Raise $1 . 4B in International Share Sale , Stock Jumps 16 % ',
#    'seendate': '20250910T123000Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/7db30b70a96bd3091d9de599ed87d15fee528308-1686x972.png',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.bloomberg.com:443/news/articles/2025-09-08/how-bitcoin-ether-are-rallying-as-trump-embraces-crypto',
#    'url_mobile': '',
#    'title': 'How Bitcoin , Ether Are Rallying as Trump Embraces Crypto',
#    'seendate': '20250910T031500Z',
#    'socialimage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/i3g4fPmskyUE/v0/1200x800.jpg',
#    'domain': 'bloomberg.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.coindesk.com/markets/2025/08/29/bitcoin-hammered-below-usd109k-as-conference-indicator-strikes-again',
#    'url_mobile': '',
#    'title': 'Bitcoin Price ( BTC ) News : Losses Extend to Nearly 8 % for the Week',
#    'seendate': '20250829T151500Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/80f2f833ba0f2c369edfb8875c4b8cbd636e7e6e-1440x1080.jpg',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.bloomberg.com/news/articles/2025-08-28/hk-official-skips-crypto-event-to-avoid-eric-trump-scmp-says',
#    'url_mobile': '',
#    'title': 'HK Official Skips Crypto Event to Avoid Eric Trump , SCMP Says',
#    'seendate': '20250828T040000Z',
#    'socialimage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/i5.r9gKE8kV8/v0/1200x800.jpg',
#    'domain': 'bloomberg.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.coindesk.com/policy/2025/08/20/there-s-no-question-in-the-world-bitcoin-will-be-worth-usd1m-eric-trump',
#    'url_mobile': '',
#    'title': 'There  No Question In The World  Bitcoin Will Be Worth $1M : Eric Trump',
#    'seendate': '20250821T020000Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/cc32713a2f5169969007038b58247bcca0b2b52b-2478x1858.jpg',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.coindesk.com/policy/2025/08/20/trump-s-crypto-conflicts-of-interest-are-blocking-dem-legislation-support-top-lawmaker-says',
#    'url_mobile': '',
#    'title': 'Trump Crypto  Conflicts of Interest  Are  Blocking  Dem Legislation Support , Top Lawmaker Says',
#    'seendate': '20250821T020000Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/a47153b115d6325103a66bbbb11e5a20db430c3a-2237x1678.jpg',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.coindesk.com/policy/2025/08/20/winklevoss-twins-heave-usd21m-toward-republicans-in-next-year-s-congressional-battles',
#    'url_mobile': '',
#    'title': 'Winklevoss Twins Heave $21M Toward Republicans in Next Year Congressional Battles',
#    'seendate': '20250820T210000Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/ca53c8e65ffc5a67c73c11a9b58b768c4afa1dc1-2532x1424.jpg',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.coindesk.com/markets/2025/08/14/u-s-confirms-plans-to-purchase-bitcoin-for-strategic-reserve-after-policy-shift',
#    'url_mobile': '',
#    'title': 'Bitcoin News ( BTC ): Strategic Reserve Purchases May Still Be in Play',
#    'seendate': '20250814T233000Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/6f837aaf3aec6acac748e5a0c637ae3a62c6c5fe-8256x5504.jpg',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.coindesk.com/markets/2025/08/14/bitcoin-crosses-google-to-become-fifth-largest-asset-as-fed-rate-cut-bets-rise',
#    'url_mobile': '',
#    'title': 'Bitcoin Price News : What Next as BTC Crosses Google to Become Fifth - Largest Asset',
#    'seendate': '20250814T134500Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/97923967111fc17f0fde0f4fbc3b5ad6e63c4396-1920x1280.jpg',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.coindesk.com/policy/2025/08/07/donald-trump-signs-order-letting-crypto-into-401-k-retirement-plans',
#    'url_mobile': '',
#    'title': 'Donald Trump Signs Order Letting Crypto Into 401 ( k ) Retirement Plans',
#    'seendate': '20250807T224500Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/13cd4f14be950fbfb70e6dc6ab16bf0fdc1d8647-4533x2550.jpg',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.bloomberg.com/news/articles/2025-08-01/bitcoin-pulls-back-to-three-week-low-after-record-breaking-july',
#    'url_mobile': '',
#    'title': 'Bitcoin Price : BTC Falls to Three - Week Low',
#    'seendate': '20250803T030000Z',
#    'socialimage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/ivn0ePIQZ2Fc/v0/1200x800.jpg',
#    'domain': 'bloomberg.com',
#    'language': 'English',
#    'sourcecountry': 'United States'},
#   {'url': 'https://www.coindesk.com/markets/2025/08/01/bitcoin-ether-start-august-on-a-shaky-note-as-dollar-index-tops-100-yen-hits-4-month-low-ahead-of-nonfarm-payrolls',
#    'url_mobile': '',
#    'title': 'Bitcoin News Today : BTC , ETH Start August on a Shaky Note as Dollar Index ( DXY ) Tops 100 Ahead of Nonfarm Payrolls',
#    'seendate': '20250801T210000Z',
#    'socialimage': 'https://cdn.sanity.io/images/s3y3vcno/production/b8ca17ed896b7798a86d4c465630294ca949fbad-1280x853.jpg',
#    'domain': 'coindesk.com',
#    'language': 'English',
#    'sourcecountry': 'United States'}]}

# %%
df
# Out:
#   Content-type: text/html; charset=utf-8
# 0           Server: GDELT API Server 2.0
# 1         Access-Control-Allow-Origin: *
# 2                 Timing-Allow-Origin: *
# 3        X-XSS-Protection: 1; mode=block
# 4                          Invalid mode.

# %%
personality = "Trump"
crypto_keywords = ["Bitcoin", "Ethereum"]
newspapers = ["wsj.com", "ft.com", "nytimes.com", "bloomberg.com", "coindesk.com"]
proximity = 5  # number of words between personality and crypto keyword

# Build domain filter
domain_filters = " OR ".join([f"domainis:{d}" for d in newspapers])

# Build crypto keyword part
if len(crypto_keywords) > 1:
    crypto_keywords_ = ' OR '.join(crypto_keywords)
else:
    crypto_keywords_ = crypto_keywords[0]

# Build nearX query for each crypto keyword
# e.g., near5:"Trump Bitcoin" OR near5:"Trump Ethereum"
near_queries = ' OR '.join([f'near{proximity}:"{personality} {c}"' for c in crypto_keywords_ .split(' OR ')])

# Combine with domains and language
full_query = f"{near_queries} sourcelang:English ({domain_filters})"

# %%
full_query
# Out:
# 'near15:"Trump Bitcoin" OR near15:"Trump Ethereum" sourcelang:English (domainis:wsj.com OR domainis:ft.com OR domainis:nytimes.com OR domainis:bloomberg.com OR domainis:coindesk.com)'

# %%
import requests
import pandas as pd
from io import StringIO

base_url = "https://api.gdeltproject.org/api/v2/gkg/gkg"
full_query = '"Trump Bitcoin"'

params = {
    "query": full_query,
    "mode": "CSV",
    "format": "CSV",
    "startdatetime": "20250720000000",
    "enddatetime": "20250930235959",
    "maxrecords": 250
}

response = requests.get(base_url, params=params)

if response.text.strip() == "":
    print("No data returned")
else:
    csv_data = StringIO(response.text)
    df = pd.read_csv(csv_data, sep='\t', quotechar='"', on_bad_lines='skip', engine='python')
    print(df[['DATE','SOURCEURL','V2Tone']].head())  # V2Tone is the tone column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[219], line 24
#      22 csv_data = StringIO(response.text)
#      23 df = pd.read_csv(csv_data, sep='\t', quotechar='"', on_bad_lines='skip', engine='python')
# ---> 24 print(df[['DATE','SOURCEURL','V2Tone']].head())  # V2Tone is the tone column
#
# File ~/miniconda3/envs/prefect_env/lib/python3.11/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniconda3/envs/prefect_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/prefect_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['DATE', 'SOURCEURL', 'V2Tone'], dtype='object')] are in the [columns]"

# %%
data_dict
# Out:
# {'articles': [{'url': 'https://www.dailymail.co.uk/news/article-15190969/trump-insider-trader-china-tariff.html',
#    'url_mobile': 'https://www.dailymail.co.uk/news/article-15190969/amp/trump-insider-trader-china-tariff.html',
#    'title': 'One minute before Trump China tariff shock - an intriguing market bet',
#    'seendate': '20251014T160000Z',
#    'socialimage': 'https://i.dailymail.co.uk/1s/2025/10/14/16/102978005-0-image-m-13_1760454464928.jpg',
#    'domain': 'dailymail.co.uk',
#    'language': 'English',
#    'sourcecountry': 'United Kingdom'},
#   {'url': 'https://economictimes.indiatimes.com/news/international/us/will-fed-chair-jerome-powells-speech-today-trigger-a-fresh-crypto-market-crash-heres-what-to-track/articleshow/124552775.cms',
#    'url_mobile': 'https://m.economictimes.com/news/international/us/will-fed-chair-jerome-powells-speech-today-trigger-a-fresh-crypto-market-crash-heres-what-to-track/amp_articleshow/124552775.cms',
#    'title': 'Social Security tax break : Will Fed Chair Jerome Powell speech today trigger a fresh crypto market crash ? Here what to track',
#    'seendate': '20251014T134500Z',
#    'socialimage': 'https://img.etimg.com/thumb/msid-124552775,width-1200,height-630,imgsize-116572,overlay-economictimes/articleshow.jpg',
#    'domain': 'economictimes.indiatimes.com',
#    'language': 'English',
#    'sourcecountry': 'India'},
#   {'url': 'https://www.livemint.com/news/donald-trump-joins-elite-club-of-bitcoin-investors-with-strategic-crypto-moves-via-trump-media-report-11760471221218.html',
#    'url_mobile': 'https://www.livemint.com/news/donald-trump-joins-elite-club-of-bitcoin-investors-with-strategic-crypto-moves-via-trump-media-report/amp-11760471221218.html',
#    'title': 'Donald Trump joins elite club of bitcoin investors with strategic crypto moves via Trump Media : Report',
#    'seendate': '20251014T220000Z',
#    'socialimage': 'https://www.livemint.com/lm-img/img/2025/10/14/600x338/Trump-0_1760471961452_1760471978256.jpg',
#    'domain': 'livemint.com',
#    'language': 'English',
#    'sourcecountry': 'India'},
#   {'url': 'https://economictimes.indiatimes.com/news/international/us/crypto-whale-linked-to-trump-slams-insider-rumors-then-opens-340-million-bitcoin-short/articleshow/124551067.cms',
#    'url_mobile': 'https://m.economictimes.com/news/international/us/crypto-whale-linked-to-trump-slams-insider-rumors-then-opens-340-million-bitcoin-short/amp_articleshow/124551067.cms',
#    'title': 'Crypto Whale shorting Bitcoin : Crypto whale linked to Trump slams insider rumors then opens $340 million Bitcoin short',
#    'seendate': '20251014T123000Z',
#    'socialimage': 'https://img.etimg.com/thumb/msid-124551553,width-1200,height-630,imgsize-39146,overlay-economictimes/articleshow.jpg',
#    'domain': 'economictimes.indiatimes.com',
#    'language': 'English',
#    'sourcecountry': 'India'},
#   {'url': 'https://economictimes.indiatimes.com/news/international/us/barron-trump-us-presidents-19-year-old-crypto-guru-son-is-worth-this-much-surpasses-mother-melania/articleshow/124562446.cms',
#    'url_mobile': 'https://m.economictimes.com/news/international/us/barron-trump-us-presidents-19-year-old-crypto-guru-son-is-worth-this-much-surpasses-mother-melania/amp_articleshow/124562446.cms',
#    'title': 'Barron Trump , US President 19 - year - old crypto guru son is worth this much ; surpasses mother Melania',
#    'seendate': '20251014T214500Z',
#    'socialimage': 'https://img.etimg.com/thumb/msid-124562445,width-1200,height-630,imgsize-23468,overlay-economictimes/articleshow.jpg',
#    'domain': 'economictimes.indiatimes.com',
#    'language': 'English',
#    'sourcecountry': 'India'}]}

# %%
s[:10]
# Out:
# '{"articles'

# %%
class GDELTBitcoinScraper:
    """
    Scraper for fetching Bitcoin-related news from GDELT DOC 2.0 API
    """
    
    def __init__(self):
        self.base_url = "https://api.gdeltproject.org/api/v2/doc/doc"
        
    def build_query_url(self, 
                       keywords,
                       mode="artlist",
                       max_records=250,
                       timespan="3months",
                       source_lang="English",
                       format_type="json",
                       domains=None,
                       tone=None):
        """
        Build GDELT API query URL
        
        Parameters:
        - keywords: str or list, search terms
        - mode: str, output mode (artlist, timelinevol, timelinevolraw, etc.)
        - max_records: int, number of records (1-250 for artlist)
        - timespan: str, time period (e.g., "24hours", "3months", "1week")
        - source_lang: str, language filter
        - format_type: str, output format (json, csv, html)
        - domains: str or list, specific domains to search
        - tone: str, tone filter (e.g., ">5" for positive, "<-5" for negative)
        """
        
        # Handle keywords - quote terms with spaces or special characters
        def needs_quotes(term):
            """Check if a term needs quotes (has spaces or special chars)"""
            special_chars = ['-', '_', '/', '\\', ':', ';', ',', '.', '!', '?']
            return ' ' in term or any(char in term for char in special_chars)
        
        if isinstance(keywords, list):
            query = " ".join([f'"{kw}"' if needs_quotes(kw) else kw for kw in keywords])
        else:
            query = f'"{keywords}"' if needs_quotes(keywords) else keywords
            
        # Build query parameters
        params = [f"query={quote(query)}"]
        
        if source_lang:
            params.append(f"sourcelang:{source_lang}")
            
        if domains:
            if isinstance(domains, list):
                for domain in domains:
                    params.append(f"domainis:{domain}")
            else:
                params.append(f"domainis:{domains}")
                
        if tone:
            params.append(f"tone:{tone}")
        
        # Join query parameters
        query_string = " ".join(params)
        
        # Build full URL
        url = f"{self.base_url}?query={quote(query_string)}"
        url += f"&mode={mode}"
        url += f"&format={format_type}"
        url += f"&timespan={timespan}"
        
        if mode == "artlist":
            url += f"&maxrecords={max_records}"
            
        return url
    
    def fetch_articles(self, 
                      keywords=["bitcoin", "cryptocurrency"],
                      max_records=250,
                      timespan="3months",
                      domains=None):
        """
        Fetch article list from GDELT
        
        Returns: DataFrame with columns: title, url, domain, language, 
                 seendate, sourcecountry
        """
        
        url = self.build_query_url(
            keywords=keywords,
            mode="artlist",
            max_records=max_records,
            timespan=timespan,
            domains=domains
        )
        
        print(f"Fetching from: {url}")
        
        try:
            response = requests.get(url, timeout=30)
            response.raise_for_status()
            data = response.json()
            
            if "articles" in data and data["articles"]:
                df = pd.DataFrame(data["articles"])
                
                # Convert seendate to datetime
                if "seendate" in df.columns:
                    df["seendate"] = pd.to_datetime(df["seendate"], format="%Y%m%dT%H%M%SZ")
                
                print(f"Fetched {len(df)} articles")
                return df
            else:
                print("No articles found")
                return pd.DataFrame()
                
        except requests.exceptions.RequestException as e:
            print(f"Error fetching data: {e}")
            return pd.DataFrame()
    
    def fetch_timeline(self, 
                      keywords=["bitcoin"],
                      timespan="1month",
                      mode="timelinevolraw"):
        """
        Fetch timeline data showing article volume over time
        
        Parameters:
        - mode: "timelinevol" (percentage) or "timelinevolraw" (raw counts)
        
        Returns: DataFrame with datetime and volume columns
        """
        
        url = self.build_query_url(
            keywords=keywords,
            mode=mode,
            timespan=timespan
        )
        
        print(f"Fetching timeline from: {url}")
        
        try:
            response = requests.get(url, timeout=30)
            response.raise_for_status()
            data = response.json()
            
            if "timeline" in data and data["timeline"]:
                timeline = data["timeline"][0]
                
                # Parse data points
                dates = []
                values = []
                
                for item in timeline.get("data", []):
                    dates.append(datetime.strptime(item["date"], "%Y-%m-%d %H:%M:%S"))
                    values.append(item["value"])
                
                df = pd.DataFrame({
                    "datetime": dates,
                    "article_count": values
                })
                
                print(f"Fetched {len(df)} timeline data points")
                return df
            else:
                print("No timeline data found")
                return pd.DataFrame()
                
        except requests.exceptions.RequestException as e:
            print(f"Error fetching timeline: {e}")
            return pd.DataFrame()
    
    def fetch_batch_articles(self, 
                            keywords=["bitcoin"],
                            days_back=90,
                            batch_size=7):
        """
        Fetch articles in batches by date ranges to get more historical data
        
        Parameters:
        - days_back: int, how many days back to fetch
        - batch_size: int, days per batch (GDELT has 250 article limit per query)
        
        Returns: Combined DataFrame of all articles
        """
        
        all_articles = []
        end_date = datetime.now()
        
        for i in range(0, days_back, batch_size):
            batch_end = end_date - timedelta(days=i)
            batch_start = end_date - timedelta(days=i + batch_size)
            
            # Format dates for GDELT
            timespan = f"{batch_size}days"
            
            print(f"\nFetching batch: {batch_start.date()} to {batch_end.date()}")
            
            df = self.fetch_articles(
                keywords=keywords,
                timespan=timespan,
                max_records=250
            )
            
            if not df.empty:
                all_articles.append(df)
            
            # Be polite to the API
            time.sleep(2)
        
        if all_articles:
            combined_df = pd.concat(all_articles, ignore_index=True)
            # Remove duplicates based on URL
            combined_df = combined_df.drop_duplicates(subset=["url"])
            print(f"\nTotal unique articles: {len(combined_df)}")
            return combined_df
        else:
            return pd.DataFrame()

# # Example usage
# if __name__ == "__main__":
#     scraper = GDELTBitcoinScraper()
    
#     # Example 1: Fetch recent Bitcoin articles
#     print("=" * 50)
#     print("Fetching Bitcoin articles from last 24 hours")
#     print("=" * 50)
#     articles = scraper.fetch_articles(
#         keywords=["bitcoin"],
#         timespan="24hours",
#         max_records=100
#     )
    
#     if not articles.empty:
#         print("\nFirst 5 articles:")
#         print(articles[["title", "seendate", "domain"]].head())
    
#     # Example 2: Fetch timeline data
#     print("\n" + "=" * 50)
#     print("Fetching Bitcoin timeline for last 30 days")
#     print("=" * 50)
#     timeline = scraper.fetch_timeline(
#         keywords=["bitcoin"],
#         timespan="1month",
#         mode="timelinevolraw"
#     )
    
#     if not timeline.empty:
#         print("\nTimeline summary:")
#         print(timeline.describe())
    
#     # Example 3: Fetch from specific crypto news sources
#     print("\n" + "=" * 50)
#     print("Fetching from crypto-specific sources")
#     print("=" * 50)
#     crypto_articles = scraper.fetch_articles(
#         keywords=["bitcoin", "cryptocurrency"],
#         domains=["coindesk.com", "cointelegraph.com", "decrypt.co"],
#         timespan="7days",
#         max_records=250
#     )
    
#     if not crypto_articles.empty:
#         print(f"\nFound {len(crypto_articles)} articles from crypto sources")
#         print("\nDomain distribution:")
#         print(crypto_articles["domain"].value_counts())
    
#     # Example 4: Search for Bitcoin + specific events
#     print("\n" + "=" * 50)
#     print("Searching for Bitcoin regulation news")
#     print("=" * 50)
#     regulation_articles = scraper.fetch_articles(
#         keywords=["bitcoin", "regulation"],
#         timespan="30days",
#         max_records=100
#     )
    
#     if not regulation_articles.empty:
#         print(f"\nFound {len(regulation_articles)} regulation-related articles")

# %%
scraper = GDELTBitcoinScraper()

# Example 1: Fetch recent Bitcoin articles
print("=" * 50)
print("Fetching Bitcoin articles from last 24 hours")
print("=" * 50)
articles = scraper.fetch_articles(
    keywords=["bitcoin"],
    timespan="24hours",
    max_records=100
)

if not articles.empty:
    print("\nFirst 5 articles:")
    print(articles[["title", "seendate", "domain"]].head())

# Example 2: Fetch timeline data
print("\n" + "=" * 50)
print("Fetching Bitcoin timeline for last 30 days")
print("=" * 50)
timeline = scraper.fetch_timeline(
    keywords=["bitcoin"],
    timespan="1month",
    mode="timelinevolraw"
)

if not timeline.empty:
    print("\nTimeline summary:")
    print(timeline.describe())

# Example 3: Fetch from specific crypto news sources
print("\n" + "=" * 50)
print("Fetching from crypto-specific sources")
print("=" * 50)
crypto_articles = scraper.fetch_articles(
    keywords=["bitcoin", "cryptocurrency"],
    domains=["coindesk.com", "cointelegraph.com", "decrypt.co"],
    timespan="7days",
    max_records=250
)

if not crypto_articles.empty:
    print(f"\nFound {len(crypto_articles)} articles from crypto sources")
    print("\nDomain distribution:")
    print(crypto_articles["domain"].value_counts())

# Example 4: Search for Bitcoin + specific events
print("\n" + "=" * 50)
print("Searching for Bitcoin regulation news")
print("=" * 50)
regulation_articles = scraper.fetch_articles(
    keywords=["bitcoin", "regulation"],
    timespan="30days",
    max_records=100
)

if not regulation_articles.empty:
    print(f"\nFound {len(regulation_articles)} regulation-related articles")
# Out:
# ==================================================
# Fetching Bitcoin articles from last 24 hours
# ==================================================
# Fetching from: https://api.gdeltproject.org/api/v2/doc/doc?query=query%3Dbitcoin%20sourcelang%3AEnglish&mode=artlist&format=json&timespan=24hours&maxrecords=100
# Error fetching data: Expecting value: line 1 column 1 (char 0)
#
# ==================================================
# Fetching Bitcoin timeline for last 30 days
# ==================================================
# Fetching timeline from: https://api.gdeltproject.org/api/v2/doc/doc?query=query%3Dbitcoin%20sourcelang%3AEnglish&mode=timelinevolraw&format=json&timespan=1month
# Error fetching timeline: Expecting value: line 1 column 1 (char 0)
#
# ==================================================
# Fetching from crypto-specific sources
# ==================================================
# Fetching from: https://api.gdeltproject.org/api/v2/doc/doc?query=query%3Dbitcoin%2520cryptocurrency%20sourcelang%3AEnglish%20domainis%3Acoindesk.com%20domainis%3Acointelegraph.com%20domainis%3Adecrypt.co&mode=artlist&format=json&timespan=7days&maxrecords=250
# Error fetching data: Expecting value: line 1 column 1 (char 0)
#
# ==================================================
# Searching for Bitcoin regulation news
# ==================================================
# Fetching from: https://api.gdeltproject.org/api/v2/doc/doc?query=query%3Dbitcoin%2520regulation%20sourcelang%3AEnglish&mode=artlist&format=json&timespan=30days&maxrecords=100
# Error fetching data: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Test BIG QUERY

# %%
from google.cloud import bigquery
import pandas as pd
import os

# Initialize client
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../keys/crypto-tracker.json'

PROJECT_ID='crypto-tracker-475407'
client = bigquery.Client(project=PROJECT_ID)

# %%
query = """
SELECT 
  DATE,
  SourceCommonName,
  DocumentIdentifier,
  V2Themes,
  V2Tone,
  AllNames
FROM `gdelt-bq.gdeltv2.gkg`
WHERE 
  DATE BETWEEN 20250101 AND 20250105
  AND (
    LOWER(SourceCommonName) = 'nytimes.com'
    OR DocumentIdentifier LIKE '%nytimes.com%'
  )
LIMIT 10
"""

result = client.query(query).result()
for row in result:
    print(f"Success! Found {row.test_count} articles")
    print("BigQuery is properly configured!")

# %%
# Query for Trump AND Crypto articles
query = """
SELECT 
  DATE,
  SourceCommonName,
  DocumentIdentifier,
  V2Themes,
  V2Tone,
  V2Persons,
  V2Organizations
FROM `gdelt-bq.gdeltv2.gkg_partitioned`
WHERE 
  _PARTITIONTIME BETWEEN '2025-01-15' AND '2025-01-17'  -- Just 3 days for now
  AND (
    LOWER(V2Persons) LIKE '%trump%'
    OR LOWER(AllNames) LIKE '%donald trump%'
  )
  AND (
    LOWER(V2Themes) LIKE '%crypto%'
    OR LOWER(V2Themes) LIKE '%bitcoin%'
    OR LOWER(V2Themes) LIKE '%cryptocurrency%'
    OR LOWER(V2Themes) LIKE '%blockchain%'
    OR LOWER(V2Themes) LIKE '%ethereum%'
    OR LOWER(AllNames) LIKE '%bitcoin%'
    OR LOWER(AllNames) LIKE '%crypto%'
    OR LOWER(V2Organizations) LIKE '%coinbase%'
    OR LOWER(V2Organizations) LIKE '%binance%'
  )
  AND LOWER(SourceCommonName) IN (
    'nytimes.com',
    'washingtonpost.com',
    'wsj.com',
    'reuters.com',
    'bloomberg.com',
    'cnbc.com',
    'coindesk.com',
    'cointelegraph.com'
  )
LIMIT 200
"""

result = client.query(query).result()
count = 0
for row in result:
    count += 1
    print(f"Date: {row.DATE}")
    print(f"Source: {row.SourceCommonName}")
    print(f"URL: {row.DocumentIdentifier}")
    print("---")

if count == 0:
    print("No results found!")
else:
    print(f"Found {count} articles")
# Out:
# Date: 20250115103000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/15/opinion/pam-bondi-trump.html
# ---
# Date: 20250115103000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/15/opinion/trump-mckinley-tarriffs.html
# ---
# Date: 20250115103000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/15/opinion/trump-catholic-church-immigrants-deportation.html
# ---
# Date: 20250115103000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/15/opinion/trump-democracy-autocracy.html
# ---
# Date: 20250115184500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/15/opinion/trump-ceasefire-israel-hamas.html
# ---
# Date: 20250115000000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/14/briefing/pete-hegseth-hearing-la-fires-wind.html
# ---
# Date: 20250322231500
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6223677/2025/03/22/marsch-disrespect-canada-usmnt-nations-league/
# ---
# Date: 20250209214500
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6120652/2025/02/08/super-bowl-new-orleans-homeless/
# ---
# Date: 20250209231500
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6124820/2025/02/09/donald-trump-fox-super-bowl-interview-chiefs-eagles/
# ---
# Date: 20250115141500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/15/business/dealbook/zuckerberg-bezos-trump-inauguration.html
# ---
# Date: 20250303011500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/03/02/us/politics/democrats-trump-federal-workers.html
# ---
# Date: 20250225233000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/25/opinion/trump-putin-ukraine.html
# ---
# Date: 20250214230000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/14/opinion/emil-bove-danielle-sassoon-doj-trump.html
# ---
# Date: 20250121001500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/briefing/trump-inauguration-executive-orders-gaza-cease-fire.html
# ---
# Date: 20250121004500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/us/politics/trump-inauguration-promises.html
# ---
# Date: 20250121004500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/us/politics/trump-hand-bible-oath.html
# ---
# Date: 20250121004500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/briefing/trump-is-sworn-in-as-president.html
# ---
# Date: 20250121004500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/us/politics/trump-sworn-in-president.html
# ---
# Date: 20250121031500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/opinion/president-trump-inauguration.html
# ---
# Date: 20250121031500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/opinion/trump-jan-6-pardons.html
# ---
# Date: 20250204220000
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6112317/2025/02/04/nfl-end-racism-super-bowl-dei-trump/
# ---
# Date: 20250120223000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/business/media/media-msnbc-fox-news-inaugural.html
# ---
# Date: 20250120224500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/us/politics/at-inauguration-melania-and-barron-trump-greet-a-limelight-they-once-avoided.html
# ---
# Date: 20250120230000
# Source: nytimes.com
# URL: https://www.nytimes.com/interactive/2025/01/20/us/politics/presidents-inaugural-address-speech.html
# ---
# Date: 20250120230000
# Source: nytimes.com
# URL: https://www.nytimes.com/live/2025/01/20/opinion/thepoint/democrats-trump-inauguration-elections
# ---
# Date: 20250120230000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/20/us/politics/baron-melania-trump-inauguration.html
# ---
# Date: 20250201123000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/01/opinion/amy-klobuchar-interview-democrats-trump.html
# ---
# Date: 20250118004500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/17/us/politics/democrats-frame-trumps-friends-as-foes.html
# ---
# Date: 20250118004500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/17/opinion/gaza-israel-hamas-hostages-cease-fire.html
# ---
# Date: 20250206031500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/05/opinion/usaid-spending-trump-musk.html
# ---
# Date: 20250131103000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/31/arts/television/late-night-trump-dei.html
# ---
# Date: 20250208163000
# Source: nytimes.com
# URL: https://www.nytimes.com/live/2025/02/08/us/trump-administration-news
# ---
# Date: 20250222030000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/21/books/review/all-or-nothing-michael-wolff.html
# ---
# Date: 20250204013000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/03/opinion/trump-musk-iraq-takeover.html
# ---
# Date: 20250123103000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/23/opinion/trump-executive-orders-climate.html
# ---
# Date: 20250123224500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/23/opinion/trump-mckinley-populism.html
# ---
# Date: 20250121190000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/21/opinion/i-spent-trumps-inauguration-in-ukraine-this-is-what-i-saw.html
# ---
# Date: 20250121211500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/21/us/panama-canal-trump-un.html
# ---
# Date: 20250128220000
# Source: nytimes.com
# URL: https://www.nytimes.com/live/2025/01/27/opinion/thepoint/iron-dome-america-missile-defense
# ---
# Date: 20250216063000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/16/opinion/ezra-klein-podcast-congress-audio-essay.html
# ---
# Date: 20250415214500
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6280658/2025/04/15/jd-vance-ohio-state-cfb-championship-trophy/
# ---
# Date: 20250122070000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/22/opinion/trump-gaza-cease-fire.html
# ---
# Date: 20250207074500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/07/opinion/us-military-weapons-pentagon.html
# ---
# Date: 20250207081500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/07/arts/television/jimmy-kimmel-trump-prayer-breakfast.html
# ---
# Date: 20250128063000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/28/opinion/deepseek-ai-trump.html
# ---
# Date: 20250119114500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/19/opinion/sean-spicer-trump-president.html
# ---
# Date: 20250119114500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/19/opinion/trump-mandate-zuckerberg-masculinity.html
# ---
# Date: 20250119114500
# Source: nytimes.com
# URL: https://www.nytimes.com/interactive/2025/01/19/opinion/democrat-republican-post-election-vibes-mood.html
# ---
# Date: 20250119114500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/19/opinion/tiktok-ban-teenagers.html
# ---
# Date: 20250119114500
# Source: nytimes.com
# URL: https://www.nytimes.com/interactive/2025/01/19/us/politics/trump-president-promises.html
# ---
# Date: 20250119114500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/19/opinion/trump-second-term.html
# ---
# Date: 20250119114500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/19/opinion/texas-catholic-immigration-paxton.html
# ---
# Date: 20250119143000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/19/arts/television/arts-television-saturday-night-live-recap.html
# ---
# Date: 20250130104500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/30/books/review/source-code-bill-gates.html
# ---
# Date: 20250222133000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/22/opinion/trump-bush-republican-disaster.html
# ---
# Date: 20250202191500
# Source: nytimes.com
# URL: https://www.nytimes.com/live/2025/01/27/opinion/thepoint/tariffs-mexico-cars-avocados-immigration
# ---
# Date: 20250208181500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/08/opinion/trump-shock-awe.html
# ---
# Date: 20250125143000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/25/opinion/trump-broke-liberal-cathedral.html
# ---
# Date: 20250216014500
# Source: nytimes.com
# URL: https://www.nytimes.com/live/2025/02/15/us/trump-news-federal/trump-administration-continues-immigration-court-crackdown-with-judge-firings
# ---
# Date: 20250203114500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/03/opinion/trump-kennedy-patel-gabbard.html
# ---
# Date: 20250304214500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/03/04/opinion/trump-zelensky-ukraine.html
# ---
# Date: 20250304203000
# Source: nytimes.com
# URL: https://www.nytimes.com/live/2025/02/25/opinion/thepoint/roosevelt-hotel-migrant-crisis-adams-biden
# ---
# Date: 20250304193000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/03/04/us/mexico-sheinbaum-trump-tariffs-retaliation.html
# ---
# Date: 20250221094500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/21/arts/television/stephen-colbert-trump-doge.html
# ---
# Date: 20250118133000
# Source: nytimes.com
# URL: https://www.nytimes.com/interactive/2025/01/17/briefing/quiz-tiktok-ceasefire-trump-biden-lynch.html
# ---
# Date: 20250118133000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/18/opinion/piketty-sandel-liberals-open-borders.html
# ---
# Date: 20250118133000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/18/opinion/trump-presidency-myth-omens.html
# ---
# Date: 20250118124500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/18/opinion/donald-trump-tech-musk-bannon.html
# ---
# Date: 20250118130000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/18/opinion/immigration-trump-ww2-japanese-internment.html
# ---
# Date: 20250118104500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/18/magazine/curtis-yarvin-interview.html
# ---
# Date: 20250118104500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/18/us/politics/trump-visual-imagery.html
# ---
# Date: 20250306041500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/03/05/nyregion/adrienne-adams-mayor-nyc.html
# ---
# Date: 20250306060000
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6177382/2025/03/06/club-world-cup-teams-clubs-2025/
# ---
# Date: 20250116214500
# Source: nytimes.com
# URL: https://www.nytimes.com/interactive/2024/10/29/learning/29StudentNewsQuiz.html
# ---
# Date: 20250116214500
# Source: nytimes.com
# URL: https://www.nytimes.com/2024/10/29/climate/donald-trump-climate-change-claims.html
# ---
# Date: 20250225014500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/24/opinion/fbi-trump-dan-bongino.html
# ---
# Date: 20250228224500
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6167098/2025/02/28/infantino-trump-world-cup/
# ---
# Date: 20250211184500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/11/opinion/trump-musk-press-media.html
# ---
# Date: 20250301171500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/03/01/opinion/columnists/trumps-lies-and-broken-promises.html
# ---
# Date: 20250125114500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/25/magazine/trump-supporters-maga-america-future.html
# ---
# Date: 20250125114500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/25/magazine/trump-hyperpolitics-resistance.html
# ---
# Date: 20250125114500
# Source: nytimes.com
# URL: https://www.nytimes.com/interactive/2025/01/24/briefing/trump-inauguration-snow-oscars-news-quiz.html
# ---
# Date: 20250125124500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/25/opinion/ezra-klein-podcast-dara-lind-matthew-yglesias.html
# ---
# Date: 20250202113000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/02/opinion/ezra-klein-podcast-trump-column-read.html
# ---
# Date: 20250411131500
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6270517/2025/04/11/f1-formula-1-trump-tariffs-effect/
# ---
# Date: 20250211213000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/11/world/americas/luis-castillo-venezuela-migrant-guantanamo-bay-trump.html
# ---
# Date: 20250403000000
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6250187/2025/04/02/nwsl-zambia-china-united-states/
# ---
# Date: 20250204104500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/04/opinion/trump-media-lawsuit-freedom.html
# ---
# Date: 20250201101500
# Source: nytimes.com
# URL: https://www.nytimes.com/2024/10/24/movies/conclave-review.html
# ---
# Date: 20250221193000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/21/opinion/trump-cabinet-musk.html
# ---
# Date: 20250319150000
# Source: nytimes.com
# URL: https://www.nytimes.com/athletic/6215337/2025/03/19/imane-khelif-olympics-donald-trump/
# ---
# Date: 20250204071500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/04/opinion/ukraine-russia-weapons-drones.html
# ---
# Date: 20250213104500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/13/opinion/trump-tax-cuts-club-for-growth.html
# ---
# Date: 20250213104500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/13/opinion/trump-authoritarianism-surrender.html
# ---
# Date: 20250228154500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/02/28/podcasts/hardfork-anthropic-dario-amodei.html
# ---
# Date: 20250128204500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/28/world/europe/hacking-democracy-elon-musk-europe.html
# ---
# Date: 20250131124500
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/31/world/trumps-deportations-only-work-if-countries-agree-to-take-their-citizens-back.html
# ---
# Date: 20250131110000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/31/opinion/trump-democratic-party-future.html
# ---
# Date: 20250131110000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/31/opinion/trump-trade-deal-china.html
# ---
# Date: 20250131110000
# Source: nytimes.com
# URL: https://www.nytimes.com/2025/01/31/opinion/trump-migration-world.html
# ---
# Found 100 articles

# %%
# Dry run - shows bytes without actually running query
job_config = bigquery.QueryJobConfig(dry_run=True, use_query_cache=False)

# Query for Trump AND Crypto articles
query = """
SELECT 
  DATE,
  SourceCommonName,
  DocumentIdentifier,
  V2Themes,
  V2Tone,
  V2Persons,
  V2Organizations
FROM `gdelt-bq.gdeltv2.gkg_partitioned`
WHERE 
  _PARTITIONTIME BETWEEN '2025-01-15' AND '2025-04-17'  -- Just 3 days for now
  AND (
    LOWER(V2Persons) LIKE '%trump%'
    OR LOWER(AllNames) LIKE '%donald trump%'
  )
  AND (
    LOWER(V2Themes) LIKE '%crypto%'
    OR LOWER(V2Themes) LIKE '%bitcoin%'
    OR LOWER(V2Themes) LIKE '%cryptocurrency%'
    OR LOWER(V2Themes) LIKE '%blockchain%'
    OR LOWER(V2Themes) LIKE '%ethereum%'
    OR LOWER(AllNames) LIKE '%bitcoin%'
    OR LOWER(AllNames) LIKE '%crypto%'
    OR LOWER(V2Organizations) LIKE '%coinbase%'
    OR LOWER(V2Organizations) LIKE '%binance%'
  )
  AND LOWER(SourceCommonName) IN (
    'nytimes.com',
    'washingtonpost.com',
    'wsj.com',
    'reuters.com',
    'bloomberg.com',
    'cnbc.com',
    'coindesk.com',
    'cointelegraph.com'
  )
LIMIT 200
"""

# This won't run the query, just estimate cost
dry_run_job = client.query(query, job_config=job_config)

bytes_scanned = dry_run_job.total_bytes_processed
gb_scanned = bytes_scanned / (1024**3)
tb_scanned = gb_scanned / 1024

print(f"This query will process: {gb_scanned:.2f} GB")
print(f"Monthly free tier remaining after query: {1024 - gb_scanned:.2f} GB")

if tb_scanned > 1:
    cost = (tb_scanned - 1) * 5
    print(f"Estimated cost: ${cost:.4f}")
else:
    print(f"Estimated cost: FREE (within 1TB free tier)")
# Out:
# This query will process: 48.97 GB
# Monthly free tier remaining after query: 975.03 GB
# Estimated cost: FREE (within 1TB free tier)
